# %%
#how to access a file inside a zipfile

import pandas as pd
import zipfile

with zipfile.ZipFile('downloads/synthea_sample_data_csv_apr2020.zip') as z:
    print(z.namelist()) #lists all files inside the ZIP

    with z.open('csv/observations.csv') as f:
         df = pd.read_csv(f)
# Out:
# ['csv/', 'csv/medications.csv', 'csv/providers.csv', 'csv/payer_transitions.csv', 'csv/imaging_studies.csv', 'csv/supplies.csv', 'csv/payers.csv', 'csv/allergies.csv', 'csv/procedures.csv', 'csv/organizations.csv', 'csv/conditions.csv', 'csv/careplans.csv', 'csv/encounters.csv', 'csv/devices.csv', 'csv/immunizations.csv', 'csv/patients.csv', 'csv/observations.csv']

# %%
   # with z.open('csv/observations.csv') as f:
    #    df = pd.read_csv(f)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299697 entries, 0 to 299696
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   DATE         299697 non-null  object
#  1   PATIENT      299697 non-null  object
#  2   ENCOUNTER    269334 non-null  object
#  3   CODE         299697 non-null  object
#  4   DESCRIPTION  299697 non-null  object
#  5   VALUE        299697 non-null  object
#  6   UNITS        286962 non-null  object
#  7   TYPE         299697 non-null  object
# dtypes: object(8)
# memory usage: 18.3+ MB
