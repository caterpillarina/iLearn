# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#only works with os. Use !dir, or magic command %ls

# %%
print('hello world')
# Out:
# hello world

# %%
# %ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is C666-4787
#
#  Directory of C:\Users\vinan
#
# 12/29/2025  12:45 AM    <DIR>          .
# 10/24/2025  12:45 AM    <DIR>          ..
# 02/24/2025  04:31 PM    <DIR>          .idlerc
# 12/29/2025  12:41 AM    <DIR>          .ipynb_checkpoints
# 12/28/2025  03:48 PM    <DIR>          .ipython
# 12/28/2025  03:43 PM    <DIR>          .jupyter
# 11/04/2024  12:03 PM    <DIR>          .ms-ad
# 10/24/2025  12:48 AM    <DIR>          Contacts
# 07/10/2024  10:32 AM    <DIR>          Documents
# 12/29/2025  12:31 AM    <DIR>          Downloads
# 10/24/2025  12:48 AM    <DIR>          Favorites
# 10/24/2025  12:48 AM    <DIR>          Links
# 10/24/2025  12:48 AM    <DIR>          Music
# 12/28/2025  11:49 PM    <DIR>          OneDrive
# 12/28/2025  03:41 PM                 0 Python Pandas practice.txt
# 10/24/2025  12:48 AM    <DIR>          Saved Games
# 10/24/2025  12:48 AM    <DIR>          Searches
# ...

# %%
# !dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is C666-4787
#
#  Directory of C:\Users\vinan
#
# 12/29/2025  12:45 AM    <DIR>          .
# 10/24/2025  12:45 AM    <DIR>          ..
# 02/24/2025  04:31 PM    <DIR>          .idlerc
# 12/29/2025  12:41 AM    <DIR>          .ipynb_checkpoints
# 12/28/2025  03:48 PM    <DIR>          .ipython
# 12/28/2025  03:43 PM    <DIR>          .jupyter
# 11/04/2024  12:03 PM    <DIR>          .ms-ad
# 10/24/2025  12:48 AM    <DIR>          Contacts
# 07/10/2024  10:32 AM    <DIR>          Documents
# 12/29/2025  12:31 AM    <DIR>          Downloads
# 10/24/2025  12:48 AM    <DIR>          Favorites
# 10/24/2025  12:48 AM    <DIR>          Links
# 10/24/2025  12:48 AM    <DIR>          Music
# 12/28/2025  11:49 PM    <DIR>          OneDrive
# 12/28/2025  03:41 PM                 0 Python Pandas practice.txt
# 10/24/2025  12:48 AM    <DIR>          Saved Games
# 10/24/2025  12:48 AM    <DIR>          Searches
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('customers.csv')

# %%
#df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.head
# Out:
# <bound method NDFrame.head of        ID First Name Last Name         Phone          LTV
# 0    4576     Sophia    Walker  602-310-9331     $496.87
# 1    9488     Evelyn    Harris  171-363-6978  $38,424.41
# 2    7265      Lucas    Foster  139-658-8905  $14,413.64
# 3    8555     Elijah     Jones  538-241-9868  $13,440.49
# 4    7023      Mason    Taylor  937-595-5837   $1,777.37
# ..    ...        ...       ...           ...          ...
# 995  7099      David    Harris  809-428-6034  $12,799.04
# 996  6743      Henry     Reyes  999-363-7716  $11,043.94
# 997  3513     Olivia   Sanders             ?  $10,206.00
# 998  4307       Emma       Cox  748-415-4613   $9,839.57
# 999  9062      Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 5 columns]>

# %%
df.head()
# Out:
#      ID First Name Last Name         Phone          LTV
# 0  4576     Sophia    Walker  602-310-9331     $496.87
# 1  9488     Evelyn    Harris  171-363-6978  $38,424.41
# 2  7265      Lucas    Foster  139-658-8905  $14,413.64
# 3  8555     Elijah     Jones  538-241-9868  $13,440.49
# 4  7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.tail()
# Out:
#        ID First Name Last Name         Phone          LTV
# 995  7099      David    Harris  809-428-6034  $12,799.04
# 996  6743      Henry     Reyes  999-363-7716  $11,043.94
# 997  3513     Olivia   Sanders             ?  $10,206.00
# 998  4307       Emma       Cox  748-415-4613   $9,839.57
# 999  9062      Henry     Brown  412-368-2550  $14,686.60

# %%
# !dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is C666-4787
#
#  Directory of C:\Users\vinan
#
# 12/29/2025  12:57 AM    <DIR>          .
# 10/24/2025  12:45 AM    <DIR>          ..
# 02/24/2025  04:31 PM    <DIR>          .idlerc
# 12/29/2025  12:41 AM    <DIR>          .ipynb_checkpoints
# 12/28/2025  03:48 PM    <DIR>          .ipython
# 12/28/2025  03:43 PM    <DIR>          .jupyter
# 11/04/2024  12:03 PM    <DIR>          .ms-ad
# 10/24/2025  12:48 AM    <DIR>          Contacts
# 12/29/2025  12:31 AM            45,067 customers.csv
# 07/10/2024  10:32 AM    <DIR>          Documents
# 12/29/2025  12:31 AM    <DIR>          Downloads
# 10/24/2025  12:48 AM    <DIR>          Favorites
# 10/24/2025  12:48 AM    <DIR>          Links
# 10/24/2025  12:48 AM    <DIR>          Music
# 12/28/2025  11:49 PM    <DIR>          OneDrive
# 12/28/2025  03:41 PM                 0 Python Pandas practice.txt
# 10/24/2025  12:48 AM    <DIR>          Saved Games
# ...

# %%
df = pd.read_csv('downloads/customers.csv')
index_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 df = pd.read_csv('downloads/customers.csv')
# ----> 2 index_
#
# NameError: name 'index_' is not defined

# %%
df = pd.read_csv('downloads/customers.csv')
index_col = id

# %%
df.head()
# Out:
#      ID First Name Last Name         Phone          LTV
# 0  4576     Sophia    Walker  602-310-9331     $496.87
# 1  9488     Evelyn    Harris  171-363-6978  $38,424.41
# 2  7265      Lucas    Foster  139-658-8905  $14,413.64
# 3  8555     Elijah     Jones  538-241-9868  $13,440.49
# 4  7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df_url = pd.read_csv('https://raw.githubusercontent.com/kimfetti/Videos/refs/heads/master/Pandas_Tips/data/customers.csv')

# %%
df_url(head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_url(head)
#
# NameError: name 'head' is not defined

# %%
df_url.head()
# Out:
#      ID First Name Last Name         Phone          LTV
# 0  4576     Sophia    Walker  602-310-9331     $496.87
# 1  9488     Evelyn    Harris  171-363-6978  $38,424.41
# 2  7265      Lucas    Foster  139-658-8905  $14,413.64
# 3  8555     Elijah     Jones  538-241-9868  $13,440.49
# 4  7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df = pd.read_csv(
    'downloads/customers.csv',
    index_col = 'ID',
    na_values = '?',
    nrows=100
)

# %%
df.head()
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 4576 to 9062
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  1000 non-null   object
#  1   Last Name   1000 non-null   object
#  2   Phone       968 non-null    object
#  3   LTV         986 non-null    object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
df.Phone.value_counts()
# Out:
# Phone
# ?               31
# 677-742-5739     1
# 412-368-2550     1
# 602-310-9331     1
# 171-363-6978     1
#                 ..
# 339-886-2967     1
# 809-428-6034     1
# 999-363-7716     1
# 748-415-4613     1
# 778-262-5262     1
# Name: count, Length: 938, dtype: int64

# %%
df.LTV.value_counts()
# Out:
# LTV
# ?              12
# $13,440.49      1
# $1,777.37       1
# $21,446.57      1
# $12,540.32      1
#                ..
# $12,799.04      1
# $11,043.94      1
# $10,206.00      1
# $9,839.57       1
# $14,413.64      1
# Name: count, Length: 975, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 4576 to 9062
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  1000 non-null   object
#  1   Last Name   1000 non-null   object
#  2   Phone       937 non-null    object
#  3   LTV         974 non-null    object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
df.Phone.value_counts()
# Out:
# Phone
# 602-310-9331    1
# 171-363-6978    1
# 139-658-8905    1
# 538-241-9868    1
# 937-595-5837    1
#                ..
# 339-886-2967    1
# 809-428-6034    1
# 999-363-7716    1
# 748-415-4613    1
# 412-368-2550    1
# Name: count, Length: 937, dtype: int64

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.tail()
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 7099      David    Harris  809-428-6034  $12,799.04
# 6743      Henry     Reyes  999-363-7716  $11,043.94
# 3513     Olivia   Sanders           NaN  $10,206.00
# 4307       Emma       Cox  748-415-4613   $9,839.57
# 9062      Henry     Brown  412-368-2550  $14,686.60

# %%
df.tail()
# Out:
#      First Name Last Name         Phone         LTV
# ID
# 2229       Emma   Simmons  613-834-3513  $4,538.32
# 5039        Ava     Brown  170-576-6081    $422.52
# 2263   Victoria     Smith  971-297-2895  $5,829.51
# 9232      Lucas     Perry  534-290-4258  $7,243.49
# 8922     Joseph  Mitchell           NaN  $3,721.42

# %%
df = pd.read_csv('downloads/pet_data.csv')

# %%
df.head()
# Out:
#       name pet_type   food_type amount    brand
# 0    Simba   Lizard     Insects   212g      NaN
# 1  Winston   Ferret    Dry Food    NaN  Pawsome
# 2    Bella   Parrot       Seeds    NaN      NaN
# 3   Shadow  Hamster     Pellets    58g      NaN
# 4     Milo   Rabbit  Vegetables   124g      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       491 non-null    object
#  1   pet_type   490 non-null    object
#  2   food_type  434 non-null    object
#  3   amount     388 non-null    object
#  4   brand      85 non-null     object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %%
df.brand.value_counts()
# Out:
# brand
# SnackLand        13
# Pawsome          12
# YummyDelight     12
# ChowTime         10
# PetPerfection    10
# TropicalFeast    10
# GreenHarvest      9
# GrainyGraze       9
# Name: count, dtype: int64

# %%
df.isnull().values.any()
# Out:
# np.True_

# %%
import seaborn as sns

# %%
import seaborn as sns

# %%
df.shape
# Out:
# (500, 5)

# %%
df.dropna()
# Out:
#         name    pet_type   food_type amount          brand
# 9      Tiger        Fish     Pellets   173g       ChowTime
# 18   Charlie         Dog  Dry Kibble    84g   GreenHarvest
# 19    Harley         Cat    Wet Food    90g        Pawsome
# 21    Jasper      Rabbit         Hay    37g      SnackLand
# 23   Mittens         Dog    Wet Food    91g  TropicalFeast
# 31   Winston        Fish     Pellets    37g    GrainyGraze
# 38     Penny  Guinea Pig     Pellets   119g  TropicalFeast
# 46      Nala      Parrot     Pellets    31g    GrainyGraze
# 57      Loki         Dog    Wet Food   173g        Pawsome
# 74       Zoe     Hamster       Seeds    49g   YummyDelight
# 75      Finn      Lizard     Pellets    94g    GrainyGraze
# 112     Ruby      Ferret    Wet Food   182g        Pawsome
# 122    Simba       Snake     Rodents    25g      SnackLand
# 129      Leo         Cat  Dry Kibble   114g    GrainyGraze
# 134     Lola      Parrot       Seeds    68g   YummyDelight
# ...

# %%
df.shape
# Out:
# (500, 5)

# %%
df.dropna().shape
# Out:
# (56, 5)

# %%
df1 = pd.DataFrame({
    'A': [1, 2, None],
    'B': [4, None, 6]
    
    })

# Drop rows with any NaN values
df1_cleaned = df1.dropna()

# %%
df1_cleaned.head()
# Out:
#      A    B
# 0  1.0  4.0

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (500, 5)

# %%
df.dropna(how = 'all')
# Out:
#         name pet_type   food_type amount          brand
# 0      Simba   Lizard     Insects   212g            NaN
# 1    Winston   Ferret    Dry Food    NaN        Pawsome
# 2      Bella   Parrot       Seeds    NaN            NaN
# 3     Shadow  Hamster     Pellets    58g            NaN
# 4       Milo   Rabbit  Vegetables   124g            NaN
# ..       ...      ...         ...    ...            ...
# 495   Shadow      Dog    Wet Food   229g  TropicalFeast
# 496     Nala    Snake        Eggs   114g            NaN
# 497     Finn   Turtle     Pellets    NaN            NaN
# 498     Finn  Hamster       Seeds    55g            NaN
# 499     Cleo   Parrot     Pellets   117g            NaN
#
# [496 rows x 5 columns]

# %%
df.dropna(subset='name')
# Out:
#         name pet_type   food_type amount          brand
# 0      Simba   Lizard     Insects   212g            NaN
# 1    Winston   Ferret    Dry Food    NaN        Pawsome
# 2      Bella   Parrot       Seeds    NaN            NaN
# 3     Shadow  Hamster     Pellets    58g            NaN
# 4       Milo   Rabbit  Vegetables   124g            NaN
# ..       ...      ...         ...    ...            ...
# 495   Shadow      Dog    Wet Food   229g  TropicalFeast
# 496     Nala    Snake        Eggs   114g            NaN
# 497     Finn   Turtle     Pellets    NaN            NaN
# 498     Finn  Hamster       Seeds    55g            NaN
# 499     Cleo   Parrot     Pellets   117g            NaN
#
# [491 rows x 5 columns]

# %%
df.dropna(axis=1,how = 'all')
# Out:
#         name pet_type   food_type amount          brand
# 0      Simba   Lizard     Insects   212g            NaN
# 1    Winston   Ferret    Dry Food    NaN        Pawsome
# 2      Bella   Parrot       Seeds    NaN            NaN
# 3     Shadow  Hamster     Pellets    58g            NaN
# 4       Milo   Rabbit  Vegetables   124g            NaN
# ..       ...      ...         ...    ...            ...
# 495   Shadow      Dog    Wet Food   229g  TropicalFeast
# 496     Nala    Snake        Eggs   114g            NaN
# 497     Finn   Turtle     Pellets    NaN            NaN
# 498     Finn  Hamster       Seeds    55g            NaN
# 499     Cleo   Parrot     Pellets   117g            NaN
#
# [500 rows x 5 columns]

# %%
missing_threshold = df.shape(0)*.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 missing_threshold = df.shape(0)*.5
#
# TypeError: 'tuple' object is not callable

# %%
df.shape(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df.shape(0)
#
# TypeError: 'tuple' object is not callable

# %%
df.shape(0)*.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df.shape(0)*.5
#
# TypeError: 'tuple' object is not callable

# %%
missing_threshold = df.shape[0]*.5

# %%
df.shape[0]
# Out:
# 500

# %%
df.shape[1]
# Out:
# 5

# %%
missing threshaold
# Out:
#   Cell In[88], line 1
#     missing threshaold
#             ^
# SyntaxError: invalid syntax

# %%
missing_threshold
# Out:
# 250.0

# %%
missing_threshold
# Out:
# 250.0

# %%
gfdfgdshfsghf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 gfdfgdshfsghf
#
# NameError: name 'gfdfgdshfsghf' is not defined

# %%
## markdown
This notebook demonstrates two approaches to pricing European FX options:
1. The analytical Black-Scholes model
2. A Monte Carlo simulation

We'll compare their outputs and visualize the convergence behavior of the simulation.
# Out:
#   Cell In[96], line 6
#     We'll compare their outputs and visualize the convergence behavior of the simulation.
#       ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
# FX Options Pricing with Black-Scholes and Monte Carlo

This notebook demonstrates two approaches to pricing European FX options:
1. The analytical Black-Scholes model
2. A Monte Carlo simulation

We will compare their outputs and visualize the convergence behavior of the simulation.
# Out:
#   Cell In[98], line 3
#     This notebook demonstrates two approaches to pricing European FX options:
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# *xfvkjxlvjjvdfjdbj*

# %% [markdown]
# **DFBcbcbc**

# %% [markdown]
# [click here](google.com)

# %%
symbol = "AAPL"
df = yf.download(symbol, start="2020-01-01", auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf

# %%
df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.468262  72.528582  71.223259  71.476600  135480400
# 2020-01-03  71.763710  72.523738  71.539322  71.696152  146322800
# 2020-01-06  72.335548  72.374154  70.634532  70.885464  118387200
# 2020-01-07  71.995369  72.600975  71.775804  72.345220  108872000
# 2020-01-08  73.153503  73.455103  71.698589  71.698589  132079200

# %%
df.head
# Out:
# <bound method NDFrame.head of Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468262   72.528582   71.223259   71.476600  135480400
# 2020-01-03   71.763710   72.523738   71.539322   71.696152  146322800
# 2020-01-06   72.335548   72.374154   70.634532   70.885464  118387200
# 2020-01-07   71.995369   72.600975   71.775804   72.345220  108872000
# 2020-01-08   73.153503   73.455103   71.698589   71.698589  132079200
# ...                ...         ...         ...         ...        ...
# 2025-12-22  270.970001  273.880005  270.510010  272.859985   36571800
# 2025-12-23  272.359985  272.500000  269.559998  270.839996   29642000
# 2025-12-24  273.809998  275.429993  272.200012  272.339996   17910600
# 2025-12-26  273.399994  275.369995  272.859985  274.160004   21455300
# 2025-12-29  273.760010  274.359985  272.350006  274.230011   23399554
#
# ...

# %%
df.shape
# Out:
# (1506, 5)

# %%
display(df)
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468262   72.528582   71.223259   71.476600  135480400
# 2020-01-03   71.763710   72.523738   71.539322   71.696152  146322800
# 2020-01-06   72.335548   72.374154   70.634532   70.885464  118387200
# 2020-01-07   71.995369   72.600975   71.775804   72.345220  108872000
# 2020-01-08   73.153503   73.455103   71.698589   71.698589  132079200
# ...                ...         ...         ...         ...        ...
# 2025-12-22  270.970001  273.880005  270.510010  272.859985   36571800
# 2025-12-23  272.359985  272.500000  269.559998  270.839996   29642000
# 2025-12-24  273.809998  275.429993  272.200012  272.339996   17910600
# 2025-12-26  273.399994  275.369995  272.859985  274.160004   21455300
# 2025-12-29  273.760010  274.359985  272.350006  274.230011   23399554
#
# [1506 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1506 entries, 2020-01-02 to 2025-12-29
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   1506 non-null   float64
#  1   (High, AAPL)    1506 non-null   float64
#  2   (Low, AAPL)     1506 non-null   float64
#  3   (Open, AAPL)    1506 non-null   float64
#  4   (Volume, AAPL)  1506 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 70.6 KB

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-12-22  270.970001  273.880005  270.510010  272.859985  36571800
# 2025-12-23  272.359985  272.500000  269.559998  270.839996  29642000
# 2025-12-24  273.809998  275.429993  272.200012  272.339996  17910600
# 2025-12-26  273.399994  275.369995  272.859985  274.160004  21455300
# 2025-12-29  273.760010  274.359985  272.350006  274.230011  23399554

# %%
df.shape[0]
# Out:
# 1506

# %%
len(df)
# Out:
# 1506

# %%
symbol.financials
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 symbol.financials
#
# AttributeError: 'str' object has no attribute 'financials'

# %%
stock = yf.Ticker('msft')

# %%
stock.financials
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                        -7.708800e+07
# Tax Rate For Calcs                                  1.760000e-01
# Normalized EBITDA                                   1.606030e+11
# Total Unusual Items                                -4.380000e+08
# Total Unusual Items Excluding Goodwill             -4.380000e+08
# Net Income From Continuing Operation Net Minori...  1.018320e+11
# Reconciled Depreciation                             3.415300e+10
# Reconciled Cost Of Revenue                          8.783100e+10
# EBITDA                                              1.601650e+11
# EBIT                                                1.260120e+11
# Net Interest Income                                 2.620000e+08
# Interest Expense                                    2.385000e+09
# Interest Income                                     2.647000e+09
# ...

# %%
import talib

# %%
print(talib.get_functions())  # Should list 150+ indicators
# Out:
# ['HT_DCPERIOD', 'HT_DCPHASE', 'HT_PHASOR', 'HT_SINE', 'HT_TRENDMODE', 'ADD', 'DIV', 'MAX', 'MAXINDEX', 'MIN', 'MININDEX', 'MINMAX', 'MINMAXINDEX', 'MULT', 'SUB', 'SUM', 'ACOS', 'ASIN', 'ATAN', 'CEIL', 'COS', 'COSH', 'EXP', 'FLOOR', 'LN', 'LOG10', 'SIN', 'SINH', 'SQRT', 'TAN', 'TANH', 'ADX', 'ADXR', 'APO', 'AROON', 'AROONOSC', 'BOP', 'CCI', 'CMO', 'DX', 'MACD', 'MACDEXT', 'MACDFIX', 'MFI', 'MINUS_DI', 'MINUS_DM', 'MOM', 'PLUS_DI', 'PLUS_DM', 'PPO', 'ROC', 'ROCP', 'ROCR', 'ROCR100', 'RSI', 'STOCH', 'STOCHF', 'STOCHRSI', 'TRIX', 'ULTOSC', 'WILLR', 'BBANDS', 'DEMA', 'EMA', 'HT_TRENDLINE', 'KAMA', 'MA', 'MAMA', 'MAVP', 'MIDPOINT', 'MIDPRICE', 'SAR', 'SAREXT', 'SMA', 'T3', 'TEMA', 'TRIMA', 'WMA', 'CDL2CROWS', 'CDL3BLACKCROWS', 'CDL3INSIDE', 'CDL3LINESTRIKE', 'CDL3OUTSIDE', 'CDL3STARSINSOUTH', 'CDL3WHITESOLDIERS', 'CDLABANDONEDBABY', 'CDLADVANCEBLOCK', 'CDLBELTHOLD', 'CDLBREAKAWAY', 'CDLCLOSINGMARUBOZU', 'CDLCONCEALBABYSWALL', 'CDLCOUNTERATTACK', 'CDLDARKCLOUDCOVER', 'CDLDOJI', 'CDLDOJISTAR
# ...

# %%
talib.get_functions()
# Out:
# ['HT_DCPERIOD',
#  'HT_DCPHASE',
#  'HT_PHASOR',
#  'HT_SINE',
#  'HT_TRENDMODE',
#  'ADD',
#  'DIV',
#  'MAX',
#  'MAXINDEX',
#  'MIN',
#  'MININDEX',
#  'MINMAX',
#  'MINMAXINDEX',
#  'MULT',
#  'SUB',
#  'SUM',
#  'ACOS',
#  'ASIN',
#  'ATAN',
#  'CEIL',
#  'COS',
#  'COSH',
#  'EXP',
#  'FLOOR',
#  'LN',
#  'LOG10',
#  'SIN',
#  'SINH',
#  'SQRT',
#  'TAN',
#  'TANH',
#  'ADX',
#  'ADXR',
#  'APO',
#  'AROON',
#  'AROONOSC',
#  'BOP',
#  'CCI',
#  'CMO',
#  'DX',
#  'MACD',
#  'MACDEXT',
#  'MACDFIX',
#  'MFI',
#  'MINUS_DI',
#  'MINUS_DM',
#  'MOM',
#  'PLUS_DI',
#  'PLUS_DM',
#  'PPO',
#  'ROC',
#  'ROCP',
#  'ROCR',
#  'ROCR100',
#  'RSI',
#  'STOCH',
#  'STOCHF',
#  'STOCHRSI',
#  'TRIX',
#  'ULTOSC',
#  'WILLR',
#  'BBANDS',
#  'DEMA',
#  'EMA',
#  'HT_TRENDLINE',
#  'KAMA',
#  'MA',
#  'MAMA',
#  'MAVP',
#  'MIDPOINT',
#  'MIDPRICE',
#  'SAR',
#  'SAREXT',
#  'SMA',
#  'T3',
#  'TEMA',
#  'TRIMA',
#  'WMA',
#  'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
# ...

# %%
import QuantLib as ql

# %%
ql.get_functions()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 ql.get_functions()
#
# AttributeError: module 'QuantLib' has no attribute 'get_functions'

# %%
ql.__version__
# Out:
# '1.40'

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468262   72.528582   71.223259   71.476600  135480400
# 2020-01-03   71.763710   72.523738   71.539322   71.696152  146322800
# 2020-01-06   72.335548   72.374154   70.634532   70.885464  118387200
# 2020-01-07   71.995369   72.600975   71.775804   72.345220  108872000
# 2020-01-08   73.153503   73.455103   71.698589   71.698589  132079200
# ...                ...         ...         ...         ...        ...
# 2025-12-22  270.970001  273.880005  270.510010  272.859985   36571800
# 2025-12-23  272.359985  272.500000  269.559998  270.839996   29642000
# 2025-12-24  273.809998  275.429993  272.200012  272.339996   17910600
# 2025-12-26  273.399994  275.369995  272.859985  274.160004   21455300
# 2025-12-29  273.760010  274.359985  272.350006  274.230011   23399554
#
# ...

# %%
df = pd.read_csv('downloads/pet_data.csv')

# %%
df[df.duplicated()]
# Out:
#        name    pet_type food_type amount brand
# 167     NaN         NaN       NaN    NaN   NaN
# 242  Cooper  Guinea Pig   Pellets    NaN   NaN
# 261     NaN         NaN       NaN    NaN   NaN
# 262     NaN         NaN       NaN    NaN   NaN
# 275   Rocky        Fish   Pellets    NaN   NaN
# 323  Stella       Snake       NaN    NaN   NaN
# 485    Luna         Cat       NaN    NaN   NaN

# %%
df.shape[0]
# Out:
# 500

# %%
df[df.duplicated(keep = False)]
# Out:
#        name    pet_type food_type amount brand
# 28   Cooper  Guinea Pig   Pellets    NaN   NaN
# 42      NaN         NaN       NaN    NaN   NaN
# 95     Luna         Cat       NaN    NaN   NaN
# 144   Rocky        Fish   Pellets    NaN   NaN
# 152  Stella       Snake       NaN    NaN   NaN
# 167     NaN         NaN       NaN    NaN   NaN
# 242  Cooper  Guinea Pig   Pellets    NaN   NaN
# 261     NaN         NaN       NaN    NaN   NaN
# 262     NaN         NaN       NaN    NaN   NaN
# 275   Rocky        Fish   Pellets    NaN   NaN
# 323  Stella       Snake       NaN    NaN   NaN
# 485    Luna         Cat       NaN    NaN   NaN

# %%
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob'],
    'age': [25, 30, 25, 35, 30],
    
})

# %%
df1.head()
# Out:
#       name  age
# 0    Alice   25
# 1      Bob   30
# 2    Alice   25
# 3  Charlie   35
# 4      Bob   30

# %%
df.drop_duplicates()
# Out:
#         name pet_type   food_type amount          brand
# 0      Simba   Lizard     Insects   212g            NaN
# 1    Winston   Ferret    Dry Food    NaN        Pawsome
# 2      Bella   Parrot       Seeds    NaN            NaN
# 3     Shadow  Hamster     Pellets    58g            NaN
# 4       Milo   Rabbit  Vegetables   124g            NaN
# ..       ...      ...         ...    ...            ...
# 495   Shadow      Dog    Wet Food   229g  TropicalFeast
# 496     Nala    Snake        Eggs   114g            NaN
# 497     Finn   Turtle     Pellets    NaN            NaN
# 498     Finn  Hamster       Seeds    55g            NaN
# 499     Cleo   Parrot     Pellets   117g            NaN
#
# [493 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       491 non-null    object
#  1   pet_type   490 non-null    object
#  2   food_type  434 non-null    object
#  3   amount     388 non-null    object
#  4   brand      85 non-null     object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %%
df.info
# Out:
# <bound method DataFrame.info of         name pet_type   food_type amount          brand
# 0      Simba   Lizard     Insects   212g            NaN
# 1    Winston   Ferret    Dry Food    NaN        Pawsome
# 2      Bella   Parrot       Seeds    NaN            NaN
# 3     Shadow  Hamster     Pellets    58g            NaN
# 4       Milo   Rabbit  Vegetables   124g            NaN
# ..       ...      ...         ...    ...            ...
# 495   Shadow      Dog    Wet Food   229g  TropicalFeast
# 496     Nala    Snake        Eggs   114g            NaN
# 497     Finn   Turtle     Pellets    NaN            NaN
# 498     Finn  Hamster       Seeds    55g            NaN
# 499     Cleo   Parrot     Pellets   117g            NaN
#
# [500 rows x 5 columns]>

# %%
df.shape
# Out:
# (500, 5)

# %%
df_wo_dup=df.drop_duplicates()

# %%
df_wo_dup.shape
# Out:
# (493, 5)

# %%
df[]
# Out:
#   Cell In[172], line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
df[df.duplicated()]
# Out:
#        name    pet_type food_type amount brand
# 167     NaN         NaN       NaN    NaN   NaN
# 242  Cooper  Guinea Pig   Pellets    NaN   NaN
# 261     NaN         NaN       NaN    NaN   NaN
# 262     NaN         NaN       NaN    NaN   NaN
# 275   Rocky        Fish   Pellets    NaN   NaN
# 323  Stella       Snake       NaN    NaN   NaN
# 485    Luna         Cat       NaN    NaN   NaN

# %%
df[how='all']
# Out:
#   Cell In[175], line 1
#     df[how='all']
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df() 
# TIL: to show entire dataframe, just use df .
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 df()
#       2 # TIL: to show entire dataframe, just use df .
#
# TypeError: 'DataFrame' object is not callable

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_57944\3726558592.py in ?()
# ----> 1 df.show()
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.all()
# Out:
# name         True
# pet_type     True
# food_type    True
# amount       True
# brand        True
# dtype: bool

# %%
print(df)
# Out:
#         name pet_type   food_type amount          brand
# 0      Simba   Lizard     Insects   212g            NaN
# 1    Winston   Ferret    Dry Food    NaN        Pawsome
# 2      Bella   Parrot       Seeds    NaN            NaN
# 3     Shadow  Hamster     Pellets    58g            NaN
# 4       Milo   Rabbit  Vegetables   124g            NaN
# ..       ...      ...         ...    ...            ...
# 495   Shadow      Dog    Wet Food   229g  TropicalFeast
# 496     Nala    Snake        Eggs   114g            NaN
# 497     Finn   Turtle     Pellets    NaN            NaN
# 498     Finn  Hamster       Seeds    55g            NaN
# 499     Cleo   Parrot     Pellets   117g            NaN
#
# [500 rows x 5 columns]

# %%
df
# Out:
#         name pet_type   food_type amount          brand
# 0      Simba   Lizard     Insects   212g            NaN
# 1    Winston   Ferret    Dry Food    NaN        Pawsome
# 2      Bella   Parrot       Seeds    NaN            NaN
# 3     Shadow  Hamster     Pellets    58g            NaN
# 4       Milo   Rabbit  Vegetables   124g            NaN
# ..       ...      ...         ...    ...            ...
# 495   Shadow      Dog    Wet Food   229g  TropicalFeast
# 496     Nala    Snake        Eggs   114g            NaN
# 497     Finn   Turtle     Pellets    NaN            NaN
# 498     Finn  Hamster       Seeds    55g            NaN
# 499     Cleo   Parrot     Pellets   117g            NaN
#
# [500 rows x 5 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df.drop_duplicates(subset = 'name')
# Out:
#         name    pet_type   food_type amount          brand
# 0      Simba      Lizard     Insects   212g            NaN
# 1    Winston      Ferret    Dry Food    NaN        Pawsome
# 2      Bella      Parrot       Seeds    NaN            NaN
# 3     Shadow     Hamster     Pellets    58g            NaN
# 4       Milo      Rabbit  Vegetables   124g            NaN
# 5        Zoe      Ferret    Dry Food   114g            NaN
# 6     Casper      Rabbit  Vegetables    62g            NaN
# 7      Gizmo      Lizard     Insects   179g            NaN
# 8       Lily     Hamster       Seeds   149g            NaN
# 9      Tiger        Fish     Pellets   173g       ChowTime
# 11   Mittens         Dog  Dry Kibble    87g            NaN
# 12      Zeus         Dog    Wet Food    NaN            NaN
# 13       Leo        Fish         NaN   115g            NaN
# 14      Lucy         Dog    Wet Food   142g            NaN
# 16     Rosie         Cat    Wet Food    67g            NaN
# ...

# %%
df.drop_duplicates(subset = 'name').name.value_counts()
# Out:
# name
# Simba      1
# Winston    1
# Bella      1
# Shadow     1
# Milo       1
# Zoe        1
# Casper     1
# Gizmo      1
# Lily       1
# Tiger      1
# Mittens    1
# Zeus       1
# Leo        1
# Lucy       1
# Rosie      1
# Charlie    1
# Harley     1
# Jasper     1
# Sophie     1
# Max        1
# Duke       1
# Cooper     1
# Tucker     1
# Lulu       1
# Coco       1
# Rocky      1
# Penny      1
# Chloe      1
# Buddy      1
# Nala       1
# Kitty      1
# Ruby       1
# Stella     1
# Sadie      1
# Loki       1
# Luna       1
# Molly      1
# Lola       1
# Finn       1
# Oliver     1
# Oscar      1
# Bailey     1
# Riley      1
# Mocha      1
# Daisy      1
# Cleo       1
# Name: count, dtype: int64

# %%
df.name.value_counts()
# Out:
# name
# Luna       18
# Charlie    18
# Lucy       16
# Oliver     15
# Lily       15
# Cooper     14
# Oscar      14
# Chloe      14
# Lola       14
# Sophie     13
# Winston    13
# Shadow     13
# Stella     13
# Finn       13
# Mocha      13
# Zoe        12
# Nala       12
# Kitty      12
# Loki       12
# Riley      12
# Harley     11
# Coco       11
# Jasper     11
# Tiger      10
# Sadie      10
# Duke       10
# Buddy      10
# Simba       9
# Milo        9
# Zeus        9
# Mittens     9
# Lulu        9
# Penny       9
# Leo         9
# Ruby        9
# Rocky       8
# Casper      7
# Molly       7
# Bailey      7
# Tucker      7
# Max         7
# Gizmo       6
# Cleo        6
# Bella       5
# Rosie       5
# Daisy       5
# Name: count, dtype: int64

# %%
df.drop_duplicates(subset = ['name', 'pet_type'])
# Out:
#         name pet_type   food_type amount     brand
# 0      Simba   Lizard     Insects   212g       NaN
# 1    Winston   Ferret    Dry Food    NaN   Pawsome
# 2      Bella   Parrot       Seeds    NaN       NaN
# 3     Shadow  Hamster     Pellets    58g       NaN
# 4       Milo   Rabbit  Vegetables   124g       NaN
# ..       ...      ...         ...    ...       ...
# 486     Luna  Hamster       Seeds    53g       NaN
# 489    Rocky   Lizard     Insects   135g  ChowTime
# 491    Mocha   Turtle     Pellets   249g       NaN
# 493   Shadow      Dog    Wet Food   176g       NaN
# 494      NaN   Turtle     Pellets   162g       NaN
#
# [323 rows x 5 columns]

# %%
df.drop_duplicates(subset = ['name', 'pet_type'])[['name','pet_type']]
# Out:
#         name pet_type
# 0      Simba   Lizard
# 1    Winston   Ferret
# 2      Bella   Parrot
# 3     Shadow  Hamster
# 4       Milo   Rabbit
# ..       ...      ...
# 486     Luna  Hamster
# 489    Rocky   Lizard
# 491    Mocha   Turtle
# 493   Shadow      Dog
# 494      NaN   Turtle
#
# [323 rows x 2 columns]

# %%
df = pd.read_csv('customers.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 df = pd.read_csv('customers.csv')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv('downloads/customers.csv')

# %%
df.head()
# Out:
#      ID First Name Last Name         Phone          LTV
# 0  4576     Sophia    Walker  602-310-9331     $496.87
# 1  9488     Evelyn    Harris  171-363-6978  $38,424.41
# 2  7265      Lucas    Foster  139-658-8905  $14,413.64
# 3  8555     Elijah     Jones  538-241-9868  $13,440.49
# 4  7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.rename({'First Name' : 'First_Name'}, axis = 1)
# Out:
#        ID First_Name Last Name         Phone          LTV
# 0    4576     Sophia    Walker  602-310-9331     $496.87
# 1    9488     Evelyn    Harris  171-363-6978  $38,424.41
# 2    7265      Lucas    Foster  139-658-8905  $14,413.64
# 3    8555     Elijah     Jones  538-241-9868  $13,440.49
# 4    7023      Mason    Taylor  937-595-5837   $1,777.37
# ..    ...        ...       ...           ...          ...
# 995  7099      David    Harris  809-428-6034  $12,799.04
# 996  6743      Henry     Reyes  999-363-7716  $11,043.94
# 997  3513     Olivia   Sanders             ?  $10,206.00
# 998  4307       Emma       Cox  748-415-4613   $9,839.57
# 999  9062      Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 5 columns]

# %%
df.rename(columns={'First Name' : 'First_Name'})
# Out:
#        ID First_Name Last Name         Phone          LTV
# 0    4576     Sophia    Walker  602-310-9331     $496.87
# 1    9488     Evelyn    Harris  171-363-6978  $38,424.41
# 2    7265      Lucas    Foster  139-658-8905  $14,413.64
# 3    8555     Elijah     Jones  538-241-9868  $13,440.49
# 4    7023      Mason    Taylor  937-595-5837   $1,777.37
# ..    ...        ...       ...           ...          ...
# 995  7099      David    Harris  809-428-6034  $12,799.04
# 996  6743      Henry     Reyes  999-363-7716  $11,043.94
# 997  3513     Olivia   Sanders             ?  $10,206.00
# 998  4307       Emma       Cox  748-415-4613   $9,839.57
# 999  9062      Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 5 columns]

# %%
stock = yf.Ticker('nvda')

# %%
stock.financials
# Out:
#                                                       2025-01-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.330000e-01
# Normalized EBITDA                                   8.613700e+10
# Total Unusual Items                                 0.000000e+00
# Total Unusual Items Excluding Goodwill              0.000000e+00
# Net Income From Continuing Operation Net Minori...  7.288000e+10
# Reconciled Depreciation                             1.864000e+09
# Reconciled Cost Of Revenue                          3.263900e+10
# EBITDA                                              8.613700e+10
# EBIT                                                8.427300e+10
# Net Interest Income                                 1.539000e+09
# Interest Expense                                    2.470000e+08
# Interest Income                                     1.786000e+09
# ...

# %%
stock.calendar
# Out:
# {'Dividend Date': datetime.date(2025, 12, 25),
#  'Ex-Dividend Date': datetime.date(2025, 12, 3),
#  'Earnings Date': [datetime.date(2026, 2, 25)],
#  'Earnings High': 1.59,
#  'Earnings Low': 1.49,
#  'Earnings Average': 1.52158,
#  'Revenue High': 68755000000,
#  'Revenue Low': 64609000000,
#  'Revenue Average': 65569688320}

# %%
from nasdaq import Nasdaq

# Initialize the API client
client = Nasdaq()

# Get earnings calendar (returns a pandas DataFrame)
earnings_df = client.get_earnings_calendar()

# Preview the data
print(earnings_df.head())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 from nasdaq import Nasdaq
#       3 # Initialize the API client
#       4 client = Nasdaq()
#
# ImportError: cannot import name 'Nasdaq' from 'nasdaq' (C:\Users\vinan\AppData\Local\Programs\Python\Python313\Lib\site-packages\nasdaq\__init__.py)

# %%
from nasdaq import Nasdaq
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 from nasdaq import Nasdaq
#
# ImportError: cannot import name 'Nasdaq' from 'nasdaq' (C:\Users\vinan\AppData\Local\Programs\Python\Python313\Lib\site-packages\nasdaq\__init__.py)

# %%
from nasdaq import nasdaq
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 from nasdaq import nasdaq
#
# ImportError: cannot import name 'nasdaq' from 'nasdaq' (C:\Users\vinan\AppData\Local\Programs\Python\Python313\Lib\site-packages\nasdaq\__init__.py)
